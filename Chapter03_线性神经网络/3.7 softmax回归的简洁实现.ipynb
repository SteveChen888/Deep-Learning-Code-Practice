# %% [markdown]
# # softmax回归的简洁实现
#
# 通过深度学习框架的高级API更方便地实现softmax回归模型。

# %%
import torch
from torch import nn
from d2l import torch as d2l

batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %% [markdown]
# # 初始化模型参数

# %%
net = nn.Sequential(nn.Flatten(), nn.Linear(784, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

# %% [markdown]
# # softmax回归的深度思考

# %%
loss = nn.CrossEntropyLoss(reduction='none')

# %% [markdown]
# # 优化算法

# %%
trainer = torch.optim.SGD(net.parameters(), lr=0.1)

# %% [markdown]
# # 训练
#
# 由于d2l包中现在不包含ch3的训练模型了，所以后面的就不继续了，内容和3.6其实是一样的。
#
# 后续超参数调整实验在3.6进行。

# %%
num_epochs = 10
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 num_epochs = 10
# ----> 2 train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)
#
# Cell In[14], line 15, in train_ch3(net, train_iter, test_iter, loss, num_epochs, updater)
#      13 # 标准的主训练循环，从 0 遍历到 num_epochs - 1。总计num_epochs次。
#      14 for epoch in range(num_epochs):
# ---> 15     train_metrics = train_epoch_ch3(net, train_iter, loss, updater)
#      16     test_acc = evaluate_accuracy(net, test_iter)
#      17     animator.add(epoch + 1, train_metrics + (test_acc,))
#
# Cell In[12], line 35, in train_epoch_ch3(net, train_iter, loss, updater)
#      30         updater(X.shape[0])
#      31     # l.sum(): 获取当前批次的损失总和（float() 用于将其转换为普通数值）
#      32     # accuracy(y_hat, y): 某个自定义的准确度计算函数，计算当前批次中预测正确的样本数
#      33     # y.numel(): 获取当前批次的样本总数（即 batch size）
#      34     # metric.add(...): 将这三个数值累加到 Accumulator 中
# ---> 35     metric.add(float(l.sum()), accuracy(y_hat, y), y.numel())
#      36 # 返回训练损失和训练精度
#      37 # metric[0] / metric[2]: 返回平均训练损失 = （总损失）/（总样本数）
#      38 # metric[1] / metric[2]: 返回平均训练精度 = （总正确预测数）/（总样本数）
#      39 return metric[0] / metric[2], metric[1] / metric[2]
#
# NameError: name 'accuracy' is not defined

# %% [markdown]
# # 总结
#
# 相对来说用更简洁的语句实现了softmax。
#
# 更为细致的调整调整模型超参数然后进行实验在3.6的notebook中进行。
